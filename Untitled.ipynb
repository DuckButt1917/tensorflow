# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.3.0'

# %%
 import torch

# %%
x = 1
y = 2

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
print(x)
# Out:
# 1

# %%
z = x+y

# %%
print(z)
# Out:
# 3

# %%
z
# Out:
# 3

# %%
z
# Out:
# 3

# %%
z
# Out:
# 3

# %% [raw]
# # alt +enter 생성하고 다름으로 넘어감
# ctrl + enter edit모드(esc도 가능), a를 누르면 위에 b를 누르면 아래에 셀을 생성
# 선택하고 dd 지우기

# %% [markdown]
# 메모(마크다운) 설정 변경

# %%
import numpy as np

# %%
arr = np.array([5])

# %%
ARR
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-7fa38341603f> in <module>
# ----> 1 ARR
#
# NameError: name 'ARR' is not defined

# %%
arr
# Out:
# array([5])

# %%
arr.shape
# Out:
# (1,)

# %%
arr=np.array([1, 2, 3])

# %%
arr.shape
# Out:
# (3,)

# %% [markdown]
# 1차원 이지만 값이 3개들어감

# %% [markdown]
# # 2차원

# %%
arr=np.array([[1, 2, 3]])
arr.shape
# Out:
# (1, 3)

# %%
arr=np.array([[1, 2, 3], [1, 2, 3], [1, 2, 3]])
arr.shape
# Out:
# (3, 3)

# %%
arr=np.array([[10]])
arr.shape
# Out:
# (1, 1)

# %%
arr.ndim
# Out:
# 2

# %% [markdown]
# # 다차원

# %%
arr=np.array([[[1, 2, 3], [1, 2, 3], [1, 2, 3]], [[1, 2, 3], [1, 2, 3], [1, 2, 3]], [[1, 2, 3], [1, 2, 3], [1, 2, 3]]])
arr
# Out:
# array([[[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]],
#
#        [[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]],
#
#        [[1, 2, 3],
#         [1, 2, 3],
#         [1, 2, 3]]])

# %%
arr.shape
# Out:
# (3, 3, 3)

# %%
arr=np.array([[[1], [ 2], [3]], [[1], [2], [3]], [[1], [ 2], [3]]])
arr
# Out:
# array([[[1],
#         [2],
#         [3]],
#
#        [[1],
#         [2],
#         [3]],
#
#        [[1],
#         [2],
#         [3]]])

# %%
arr.shape
# Out:
# (3, 3, 1)
